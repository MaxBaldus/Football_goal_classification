# %%
# Import all the necessary libraries

import numpy as np
import pandas as pd
from datetime import datetime as dt
import itertools

# %matplotlib inline

# %%
# Read data from the CSV into a dataframe

# Python pandas will read a csv file using utf-8 encoding defautly. 
# If the character encoding of this csv file is not utf-8, UnicodeDecodeError may occur.

loc = "/home/max/Dokumente/Projekte/Football_Game_Prediction/Data_Gathering/Buli1_2_in_Game/"
# raw_data_01 = pd.read_csv(loc + '2004_2005_01.csv', sep=',', encoding='gbk')
# raw_data_02 = pd.read_csv(loc + '2004_2005_02.csv', sep=',', encoding='gbk')
# 4 und 5 gehen nicht

# %%
raw_data_03 = pd.read_csv(loc + '2005_2006_01.csv', sep=',', encoding='gbk')
raw_data_04 = pd.read_csv(loc + '2005_2006_02.csv', sep=',', encoding='gbk')

# %%
raw_data_05 = pd.read_csv(loc + '2006_2007_01.csv', sep=',', encoding='gbk')
raw_data_06 = pd.read_csv(loc + '2006_2007_02.csv', sep=',', encoding='gbk')

# %%
raw_data_07 = pd.read_csv(loc + '2007_2008_01.csv', sep=',', encoding='gbk')
raw_data_08 = pd.read_csv(loc + '2007_2008_02.csv', sep=',', encoding='gbk')

# %%
raw_data_09 = pd.read_csv(loc + '2008_2009_01.csv', sep=',', encoding='gbk')
raw_data_10 = pd.read_csv(loc + '2008_2009_02.csv', sep=',', encoding='gbk')

# %%
raw_data_11 = pd.read_csv(loc + '2009_2010_01.csv', sep=',', encoding='gbk')
raw_data_12 = pd.read_csv(loc + '2009_2010_02.csv', sep=',', encoding='gbk')

# %%
raw_data_13 = pd.read_csv(loc + '2010_2011_01.csv', sep=',', encoding='gbk')
raw_data_14 = pd.read_csv(loc + '2010_2011_02.csv', sep=',', encoding='gbk')

# %%
raw_data_15 = pd.read_csv(loc + '2011_2012_01.csv', sep=',', encoding='gbk')
raw_data_16 = pd.read_csv(loc + '2011_2012_02.csv', sep=',', encoding='gbk')

# %%
raw_data_17 = pd.read_csv(loc + '2012_2013_01.csv', sep=',', encoding='gbk')
raw_data_18 = pd.read_csv(loc + '2012_2013_02.csv', sep=',', encoding='gbk')

# %%
raw_data_19 = pd.read_csv(loc + '2013_2014_01.csv', sep=',', encoding='gbk')
raw_data_20 = pd.read_csv(loc + '2013_2014_02.csv', sep=',', encoding='gbk')

# %%
raw_data_21 = pd.read_csv(loc + '2014_2015_01.csv', sep=',', encoding='gbk')
raw_data_22 = pd.read_csv(loc + '2014_2015_02.csv', sep=',', encoding='gbk')

# %%
raw_data_23 = pd.read_csv(loc + '2015_2016_01.csv', sep=',', encoding='gbk')
raw_data_24 = pd.read_csv(loc + '2015_2016_02.csv', sep=',', encoding='gbk')

# %%
raw_data_25 = pd.read_csv(loc + '2016_2017_01.csv', sep=',', encoding='gbk')
raw_data_26 = pd.read_csv(loc + '2016_2017_02.csv', sep=',', encoding='gbk')

# %%
raw_data_27 = pd.read_csv(loc + '2017_2018_01.csv', sep=',', encoding='gbk')
raw_data_28 = pd.read_csv(loc + '2017_2018_02.csv', sep=',', encoding='gbk')

# %%
raw_data_27 = pd.read_csv(loc + '2018_2019_01.csv', sep=',', encoding='gbk')
raw_data_28 = pd.read_csv(loc + '2018_2019_02.csv', sep=',', encoding='gbk')

# %%
raw_data_29 = pd.read_csv(loc + '2019_2020_01.csv', sep=',', encoding='gbk')
raw_data_30 = pd.read_csv(loc + '2019_2020_02.csv', sep=',', encoding='gbk')

# %%
raw_data_08
# Out:
#     Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    D2  10/08/07          Aachen         CZ Jena     2     2   D     2     1
# 1    D2  10/08/07       Osnabruck        Freiburg     2     1   H     1     0
# 2    D2  10/08/07        St Pauli         FC Koln     0     2   A     0     0
# 3    D2  12/08/07        Augsburg     Munich 1860     2     6   A     1     3
# 4    D2  12/08/07  Erzgebirge Aue  Greuther Furth     1     1   D     0     0
# ..   ..       ...             ...             ...   ...   ...  ..   ...   ...
# 301  D2  18/05/08      Hoffenheim  Greuther Furth     5     0   H     1     0
# 302  D2  18/05/08  Kaiserslautern         FC Koln     3     0   H     0     0
# 303  D2  18/05/08           Mainz        St Pauli     5     1   H     3     0
# 304  D2  18/05/08       Osnabruck       Offenbach     3     0   H     1     0
# 305  D2  18/05/08       Paderborn      M'gladbach     2     3   A     2     1
#
# ...

# %%
raw_data_27.Date
# Out:
# 0      24/08/2018
# 1      25/08/2018
# 2      25/08/2018
# 3      25/08/2018
# 4      25/08/2018
#           ...
# 301    18/05/2019
# 302    18/05/2019
# 303    18/05/2019
# 304    18/05/2019
# 305    18/05/2019
# Name: Date, Length: 306, dtype: object

# %%
# Parse data as time 

def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%d/%m/%y').date()
    

def parse_date_other(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%d/%m/%Y').date()

# funktion brauche ich nicht: form nur für obigen zwei!
def parse_date_other_2(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d').date()

# %%
raw_data_03.Date = raw_data_03.Date.apply(parse_date)   
raw_data_04.Date = raw_data_04.Date.apply(parse_date)   
raw_data_05.Date = raw_data_05.Date.apply(parse_date)  
raw_data_06.Date = raw_data_06.Date.apply(parse_date)  
raw_data_07.Date = raw_data_07.Date.apply(parse_date)  
raw_data_08.Date = raw_data_08.Date.apply(parse_date)  
raw_data_09.Date = raw_data_09.Date.apply(parse_date)  
raw_data_10.Date = raw_data_10.Date.apply(parse_date_other)  
raw_data_11.Date = raw_data_11.Date.apply(parse_date)  
raw_data_12.Date = raw_data_12.Date.apply(parse_date)  
raw_data_13.Date = raw_data_13.Date.apply(parse_date)  
raw_data_14.Date = raw_data_14.Date.apply(parse_date) 
raw_data_15.Date = raw_data_15.Date.apply(parse_date) 
raw_data_16.Date = raw_data_16.Date.apply(parse_date)  
raw_data_17.Date = raw_data_17.Date.apply(parse_date)  
raw_data_18.Date = raw_data_18.Date.apply(parse_date)  
raw_data_19.Date = raw_data_19.Date.apply(parse_date)  
raw_data_20.Date = raw_data_20.Date.apply(parse_date)  
raw_data_21.Date = raw_data_21.Date.apply(parse_date)  
raw_data_22.Date = raw_data_22.Date.apply(parse_date)  
raw_data_23.Date = raw_data_23.Date.apply(parse_date)  
raw_data_24.Date = raw_data_24.Date.apply(parse_date)  
raw_data_25.Date = raw_data_25.Date.apply(parse_date)  
raw_data_26.Date = raw_data_26.Date.apply(parse_date)  
raw_data_27.Date = raw_data_27.Date.apply(parse_date_other)  
raw_data_28.Date = raw_data_28.Date.apply(parse_date_other)  
raw_data_29.Date = raw_data_29.Date.apply(parse_date_other)  
raw_data_30.Date = raw_data_30.Date.apply(parse_date_other)

# %%
#Gets all the statistics related to gameplay
                      
columns_req = ['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR', "HS", "AS", "HST", "AST", "HC", 
                          "AC", "HF", "AF", "HY", "AY", "HR", "AR"]

# playing_statistics_03 = raw_data_03[columns_req]
# playing_statistics_04 = raw_data_04[columns_req]
playing_statistics_05 = raw_data_05[columns_req]
playing_statistics_06 = raw_data_06[columns_req]
playing_statistics_07 = raw_data_07[columns_req]
# playing_statistics_08 = raw_data_08[columns_req]
playing_statistics_09 = raw_data_09[columns_req]

#playing_statistics_10 = raw_data_10[columns_req]
playing_statistics_11 = raw_data_11[columns_req]   
#playing_statistics_12 = raw_data_12[columns_req]
playing_statistics_13 = raw_data_13[columns_req]
#playing_statistics_14 = raw_data_14[columns_req]
playing_statistics_15 = raw_data_15[columns_req]
#playing_statistics_16 = raw_data_16[columns_req]
playing_statistics_17 = raw_data_17[columns_req]
#playing_statistics_18 = raw_data_18[columns_req]
playing_statistics_19 = raw_data_19[columns_req]
#playing_statistics_20 = raw_data_20[columns_req] 

playing_statistics_21 = raw_data_21[columns_req]   
#playing_statistics_22 = raw_data_22[columns_req]
playing_statistics_23 = raw_data_23[columns_req]
#playing_statistics_24 = raw_data_24[columns_req]
playing_statistics_25 = raw_data_25[columns_req]
#playing_statistics_26 = raw_data_26[columns_req]
playing_statistics_27 = raw_data_27[columns_req]
playing_statistics_28 = raw_data_28[columns_req]
playing_statistics_29 = raw_data_29[columns_req]
playing_statistics_30 = raw_data_30[columns_req]

# %%
playing_statistics_28
# Out:
#            Date        HomeTeam       AwayTeam  FTHG  FTAG FTR  HS  AS  HST  \
# 0    2018-08-03         Hamburg  Holstein Kiel     0     3   A  14  16    3
# 1    2018-08-04          Bochum        FC Koln     0     2   A  14  15    2
# 2    2018-08-04  Greuther Furth     Sandhausen     3     1   H  16  10    5
# 3    2018-08-04      Regensburg     Ingolstadt     2     1   H  13  13    9
# 4    2018-08-05       Darmstadt      Paderborn     1     0   H   7   7    2
# ..          ...             ...            ...   ...   ...  ..  ..  ..  ...
# 301  2019-05-19  Greuther Furth       St Pauli     2     1   H  22   9    5
# 302  2019-05-19         Hamburg       Duisburg     3     0   H  22   8    8
# 303  2019-05-19      Heidenheim     Ingolstadt     4     2   H  17  17   10
# 304  2019-05-19       Magdeburg        FC Koln     1     1   D  12  17    4
# 305  2019-05-19      Regensburg     Sandhausen     2     2   D  15  12    3
#
#      AST  HC  AC  HF  AF  HY  AY  HR  AR
# ...

# %% [markdown]
# ** GOALS SCORED AND CONCEDED AT THE END OF MATCHWEEK, ARRANGED BY TEAMS AND MATCHWEEK **

# %%
# Gets the goals scored agg arranged by teams and matchweek
def get_goals_scored(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        HTGS = playing_stat.iloc[i]['FTHG']
        ATGS = playing_stat.iloc[i]['FTAG']
        teams[playing_stat.iloc[i].HomeTeam].append(HTGS)
        teams[playing_stat.iloc[i].AwayTeam].append(ATGS)
    
    # Create a dataframe for goals scored where rows are teams and cols are matchweek.
    GoalsScored = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    GoalsScored[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        GoalsScored[i] = GoalsScored[i] + GoalsScored[i-1]
    return GoalsScored



# Gets the goals conceded agg arranged by teams and matchweek
def get_goals_conceded(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        ATGC = playing_stat.iloc[i]['FTHG']
        HTGC = playing_stat.iloc[i]['FTAG']
        teams[playing_stat.iloc[i].HomeTeam].append(HTGC)
        teams[playing_stat.iloc[i].AwayTeam].append(ATGC)
    
    # Create a dataframe for goals scored where rows are teams and cols are matchweek.
    GoalsConceded = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    GoalsConceded[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        GoalsConceded[i] = GoalsConceded[i] + GoalsConceded[i-1]
    return GoalsConceded

def get_gss(playing_stat):
    GC = get_goals_conceded(playing_stat)
    GS = get_goals_scored(playing_stat)
   
    j = 0
    HTGS = []
    ATGS = []
    HTGC = []
    ATGC = []

    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        HTGS.append(GS.loc[ht][j])
        ATGS.append(GS.loc[at][j])
        HTGC.append(GC.loc[ht][j])
        ATGC.append(GC.loc[at][j])
        
        if ((i + 1)% 9) == 0:
            j = j + 1
        
    playing_stat['HTGS'] = HTGS
    playing_stat['ATGS'] = ATGS
    playing_stat['HTGC'] = HTGC
    playing_stat['ATGC'] = ATGC
    
    return playing_stat

# %%
# Apply to each dataset

playing_statistics_05 = get_gss(playing_statistics_05)
playing_statistics_06 = get_gss(playing_statistics_06)
playing_statistics_07 = get_gss(playing_statistics_07)

playing_statistics_09 = get_gss(playing_statistics_09)
playing_statistics_11 = get_gss(playing_statistics_11)
playing_statistics_13 = get_gss(playing_statistics_13)
playing_statistics_15 = get_gss(playing_statistics_15)
playing_statistics_17 = get_gss(playing_statistics_17)
playing_statistics_19 = get_gss(playing_statistics_19)

playing_statistics_21= get_gss(playing_statistics_21)
playing_statistics_23= get_gss(playing_statistics_23)
playing_statistics_25= get_gss(playing_statistics_25)
playing_statistics_27= get_gss(playing_statistics_27)
playing_statistics_28= get_gss(playing_statistics_28)
playing_statistics_29= get_gss(playing_statistics_29)
playing_statistics_30= get_gss(playing_statistics_30)
# Out:
# <ipython-input-160-24a31de75eb3>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['HTGS'] = HTGS
# <ipython-input-160-24a31de75eb3>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['ATGS'] = ATGS
# <ipython-input-160-24a31de75eb3>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
playing_statistics_19
# Out:
#            Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HS  AS  HST  \
# 0    2013-08-09  Bayern Munich     M'gladbach     3     1   H  26  11    9
# 1    2013-08-10       Augsburg       Dortmund     0     4   A  11  13    4
# 2    2013-08-10   Braunschweig  Werder Bremen     0     1   A  13  12    3
# 3    2013-08-10       Hannover      Wolfsburg     2     0   H  20  15    8
# 4    2013-08-10         Hertha  Ein Frankfurt     6     1   H  16  10    9
# ..          ...            ...            ...   ...   ...  ..  ..  ..  ...
# 301  2014-05-10     Hoffenheim   Braunschweig     3     1   H  16   6    8
# 302  2014-05-10     Leverkusen  Werder Bremen     2     1   H  14   8    6
# 303  2014-05-10          Mainz        Hamburg     3     2   H  13  20    6
# 304  2014-05-10     Schalke 04       Nurnberg     4     1   H  22  11   11
# 305  2014-05-10      Wolfsburg     M'gladbach     3     1   H  19  13   10
#
#      AST  ...  HF  AF  HY  AY  HR  AR  HTGS  ATGS  HTGC  ATGC
# ...

# %% [markdown]
# Get Home and Away Shots

# %%
# Gets the shots fired agg arranged by teams and matchweek
def get_shots_fired(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGHSF = playing_stat.iloc[i]['HS']
        # aggregated Home Team shots
        AGASF = playing_stat.iloc[i]['AS']
        # aggregated Away Team shots
        teams[playing_stat.iloc[i].HomeTeam].append(AGHSF)
        teams[playing_stat.iloc[i].AwayTeam].append(AGASF)
    
    # Create a dataframe for shots fired (goals scored) where rows are teams and cols are matchweek.
    ShotsFired = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    ShotsFired[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        ShotsFired[i] = ShotsFired[i] + ShotsFired[i-1]
    return ShotsFired




# Gets the goals conceded agg arranged by teams and matchweek
def get_shots_conceded(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGASC = playing_stat.iloc[i]['HS']
        # aggregated home team shots conceded
        AGHSC = playing_stat.iloc[i]['AS']
        # aggregated away team shots conceded
        teams[playing_stat.iloc[i].HomeTeam].append(AGHSC)
        teams[playing_stat.iloc[i].AwayTeam].append(AGASC)
    
    # Create a dataframe for goals scored where rows are teams and cols are matchweek.
    ShotsConceded = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    ShotsConceded[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        ShotsConceded[i] = ShotsConceded[i] + ShotsConceded[i-1]
    return ShotsConceded



def get_sf(playing_stat):
    SF = get_shots_fired(playing_stat)
    SC = get_shots_conceded(playing_stat)
   
    j = 0
    AGHSF = []
    AGASF = []
    AGHSC = []
    AGASC = []    

    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        AGHSF.append(SF.loc[ht][j])
        AGASF.append(SF.loc[at][j])
        AGHSC.append(SC.loc[ht][j])
        AGASC.append(SC.loc[at][j])
        
        if ((i + 1)% 9) == 0:
            j = j + 1
        
    playing_stat['AGHSF'] = AGHSF
    playing_stat['AGASF'] = AGASF
    playing_stat['AGHSC'] = AGHSC
    playing_stat['AGASC'] = AGASC
    return playing_stat

# %%
playing_statistics_05 = get_sf(playing_statistics_05)
playing_statistics_06 = get_sf(playing_statistics_06)
playing_statistics_07 = get_sf(playing_statistics_07)

playing_statistics_09 = get_sf(playing_statistics_09)
playing_statistics_11 = get_sf(playing_statistics_11)
playing_statistics_13 = get_sf(playing_statistics_13)
playing_statistics_15 = get_sf(playing_statistics_15)
playing_statistics_17 = get_sf(playing_statistics_17)
playing_statistics_19 = get_sf(playing_statistics_19)

playing_statistics_21= get_sf(playing_statistics_21)
playing_statistics_23= get_sf(playing_statistics_23)
playing_statistics_25= get_sf(playing_statistics_25)
playing_statistics_27= get_sf(playing_statistics_27)
playing_statistics_28= get_sf(playing_statistics_28)
playing_statistics_29= get_sf(playing_statistics_29)
playing_statistics_30= get_sf(playing_statistics_30)
# Out:
# <ipython-input-163-65a700481562>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGHSF'] = AGHSF
# <ipython-input-163-65a700481562>:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGASF'] = AGASF
# <ipython-input-163-65a700481562>:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
playing_statistics_15[['Date', "HomeTeam", "AwayTeam", "HS", "AS",'AGHSF', "AGASF", "AGHSC", "AGASC"]].head(50)
# Out:
#           Date        HomeTeam        AwayTeam  HS  AS  AGHSF  AGASF  AGHSC  \
# 0   2011-08-05        Dortmund         Hamburg  16   8      0      0      0
# 1   2011-08-06        Augsburg        Freiburg  11   9      0      0      0
# 2   2011-08-06         FC Koln       Wolfsburg   7  17      0      0      0
# 3   2011-08-06        Hannover      Hoffenheim   7  12      0      0      0
# 4   2011-08-06          Hertha        Nurnberg   4  13      0      0      0
# 5   2011-08-06       Stuttgart      Schalke 04  12  15      0      0      0
# 6   2011-08-06   Werder Bremen  Kaiserslautern  19   9      0      0      0
# 7   2011-08-07   Bayern Munich      M'gladbach  19   7      0      0      0
# 8   2011-08-07           Mainz      Leverkusen  22   9      0      0      0
# 9   2011-08-13        Freiburg           Mainz  18   9      9     22     11
# 10  2011-08-13         Hamburg          Hertha   9  24      8      4     16
# ...

# %% [markdown]
# Team Shots on Taget

# %%
# Gets the shots fired on target agg arranged by teams and matchweek
def get_shots_fired_target(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGHSTF = playing_stat.iloc[i]['HST']
        # aggregated Home Team shots on Taget
        AGASTF = playing_stat.iloc[i]['AST']
        # aggregated Away Team shots on Taget
        teams[playing_stat.iloc[i].HomeTeam].append(AGHSTF)
        teams[playing_stat.iloc[i].AwayTeam].append(AGASTF)
    
    # Create a dataframe for shots fired (goals scored) where rows are teams and cols are matchweek.
    ShotsFired = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    ShotsFired[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        ShotsFired[i] = ShotsFired[i] + ShotsFired[i-1]
    return ShotsFired

# Gets the goals conceded agg on target arranged by teams and matchweek
def get_shots_conceded_target(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGASTC = playing_stat.iloc[i]['HST']
        # aggregated home team shots conceded
        AGHSTC = playing_stat.iloc[i]['AST']
        # aggregated away team shots conceded
        teams[playing_stat.iloc[i].HomeTeam].append(AGHSTC)
        teams[playing_stat.iloc[i].AwayTeam].append(AGASTC)
    
    # Create a dataframe for goals scored where rows are teams and cols are matchweek.
    ShotsConceded = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    ShotsConceded[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        ShotsConceded[i] = ShotsConceded[i] + ShotsConceded[i-1]
    return ShotsConceded

def get_sf_target(playing_stat):
    SFT = get_shots_fired_target(playing_stat)
    SCT = get_shots_conceded_target(playing_stat)
    
    j = 0
    AGHSTF = []
    AGASTF = []
    AGHSTC = []
    AGASTC = []  

    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        AGHSTF.append(SFT.loc[ht][j])
        AGASTF.append(SFT.loc[at][j])
        AGHSTC.append(SCT.loc[ht][j])
        AGASTC.append(SCT.loc[at][j])
        
        if ((i + 1)% 9) == 0:
            j = j + 1
        
    playing_stat['AGHSTF'] = AGHSTF
    playing_stat['AGASTF'] = AGASTF
    playing_stat['AGHSTC'] = AGHSTC
    playing_stat['AGASTC'] = AGASTC
    
    return playing_stat

# %%
playing_statistics_05 = get_sf_target(playing_statistics_05)
playing_statistics_06 = get_sf_target(playing_statistics_06)
playing_statistics_07 = get_sf_target(playing_statistics_07)

playing_statistics_09 = get_sf_target(playing_statistics_09)
playing_statistics_11 = get_sf_target(playing_statistics_11)
playing_statistics_13 = get_sf_target(playing_statistics_13)
playing_statistics_15 = get_sf_target(playing_statistics_15)
playing_statistics_17 = get_sf_target(playing_statistics_17)
playing_statistics_19 = get_sf_target(playing_statistics_19)

playing_statistics_21= get_sf_target(playing_statistics_21)
playing_statistics_23= get_sf_target(playing_statistics_23)
playing_statistics_25= get_sf_target(playing_statistics_25)
playing_statistics_27= get_sf_target(playing_statistics_27)
playing_statistics_28= get_sf_target(playing_statistics_28)
playing_statistics_29= get_sf_target(playing_statistics_29)
playing_statistics_30= get_sf_target(playing_statistics_30)
# Out:
# <ipython-input-166-1d9d07eec275>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGHSTF'] = AGHSTF
# <ipython-input-166-1d9d07eec275>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGASTF'] = AGASTF
# <ipython-input-166-1d9d07eec275>:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
playing_statistics_17[['Date', "HomeTeam", "AwayTeam", "HST", "AST",'AGHSTF', "AGASTF", "AGHSTC", "AGASTC"]].head(50)
# Out:
#           Date            HomeTeam            AwayTeam  HST  AST  AGHSTF  \
# 0   2012-08-24            Dortmund       Werder Bremen    6    3       0
# 1   2012-08-25            Augsburg  Fortuna Dusseldorf    4    4       0
# 2   2012-08-25       Ein Frankfurt          Leverkusen    4   10       0
# 3   2012-08-25            Freiburg               Mainz    4    3       0
# 4   2012-08-25      Greuther Furth       Bayern Munich    2    9       0
# 5   2012-08-25             Hamburg            Nurnberg    5    8       0
# 6   2012-08-25          M'gladbach          Hoffenheim    3    8       0
# 7   2012-08-25           Stuttgart           Wolfsburg    5    3       0
# 8   2012-08-26            Hannover          Schalke 04    2    7       0
# 9   2012-08-31               Mainz      Greuther Furth    3    2       3
# 10  2012-09-01  Fortuna Dusseldorf          M'gladbach    0    4       4
# 11  2012-09-01          Hoffenheim       Ein Frankfurt    3    5       8
# ...

# %% [markdown]
# Team Fouls Committed

# %%
# Gets the shots fired on target agg arranged by teams and matchweek
def get_fouls(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGHF = playing_stat.iloc[i]['HF']
        # aggregated Home Team Fouls
        AGAF = playing_stat.iloc[i]['AF']
        # aggregated Away Team Fouls
        teams[playing_stat.iloc[i].HomeTeam].append(AGHF)
        teams[playing_stat.iloc[i].AwayTeam].append(AGAF)
    
    # Create a dataframe for shots fired (goals scored) where rows are teams and cols are matchweek.
    Fouls = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    Fouls[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        Fouls[i] = Fouls[i] + Fouls[i-1]
    return Fouls


def get_fouls_agg(playing_stat):
    FA = get_fouls(playing_stat)
   
    j = 0
    AGHF = []
    AGAF = []

    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        AGHF.append(FA.loc[ht][j])
        AGAF.append(FA.loc[at][j])
        
        if ((i + 1)% 9) == 0:
            j = j + 1
        
    playing_stat['AGHF'] = AGHF
    playing_stat['AGAF'] = AGAF
    return playing_stat

# %%
playing_statistics_05 = get_fouls_agg(playing_statistics_05)
playing_statistics_06 = get_fouls_agg(playing_statistics_06)
playing_statistics_07 = get_fouls_agg(playing_statistics_07)

playing_statistics_09 = get_fouls_agg(playing_statistics_09)
playing_statistics_11 = get_fouls_agg(playing_statistics_11)
playing_statistics_13 = get_fouls_agg(playing_statistics_13)
playing_statistics_15 = get_fouls_agg(playing_statistics_15)
playing_statistics_17 = get_fouls_agg(playing_statistics_17)
playing_statistics_19 = get_fouls_agg(playing_statistics_19)

playing_statistics_21= get_fouls_agg(playing_statistics_21)
playing_statistics_23= get_fouls_agg(playing_statistics_23)
playing_statistics_25= get_fouls_agg(playing_statistics_25)
playing_statistics_27= get_fouls_agg(playing_statistics_27)
playing_statistics_28= get_fouls_agg(playing_statistics_28)
playing_statistics_29= get_fouls_agg(playing_statistics_29)
playing_statistics_30= get_fouls_agg(playing_statistics_30)
# Out:
# <ipython-input-169-b2fa1f1aadea>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGHF'] = AGHF
# <ipython-input-169-b2fa1f1aadea>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGAF'] = AGAF

# %%
playing_statistics_23[['Date', "HomeTeam", "AwayTeam", "HF", "AF",'AGHF', "AGAF"]].head(50)
# Out:
#           Date       HomeTeam       AwayTeam  HF  AF  AGHF  AGAF
# 0   2015-08-14  Bayern Munich        Hamburg  10  12     0     0
# 1   2015-08-15       Augsburg         Hertha  20  22     0     0
# 2   2015-08-15      Darmstadt       Hannover  21  22     0     0
# 3   2015-08-15       Dortmund     M'gladbach  13  14     0     0
# 4   2015-08-15     Leverkusen     Hoffenheim  12  18     0     0
# 5   2015-08-15          Mainz     Ingolstadt  20  15     0     0
# 6   2015-08-15  Werder Bremen     Schalke 04   7  16     0     0
# 7   2015-08-16      Stuttgart        FC Koln  13   8     0     0
# 8   2015-08-16      Wolfsburg  Ein Frankfurt  14  19     0     0
# 9   2015-08-21         Hertha  Werder Bremen  11  16    22     7
# 10  2015-08-22  Ein Frankfurt       Augsburg  17  21    19    20
# 11  2015-08-22        FC Koln      Wolfsburg  15  11     8    14
# 12  2015-08-22        Hamburg      Stuttgart  18  22    12    13
# ...

# %% [markdown]
# Team Corners

# %%
# Gets the shots fired on target agg arranged by teams and matchweek
def get_corners_fired(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGHCF = playing_stat.iloc[i]['HC']
        # aggregated Home Team corners
        AGACF = playing_stat.iloc[i]['AC']
        # aggregated Away Team corners
        teams[playing_stat.iloc[i].HomeTeam].append(AGHCF)
        teams[playing_stat.iloc[i].AwayTeam].append(AGACF)
    
    # Create a dataframe for shots fired (goals scored) where rows are teams and cols are matchweek.
    Corners = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    Corners[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        Corners[i] = Corners[i] + Corners[i-1]
    return Corners

def get_corners_conceived(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGACC = playing_stat.iloc[i]['HC']
        # aggregated Home Team corners
        AGHCC = playing_stat.iloc[i]['AC']
        # aggregated Away Team corners
        teams[playing_stat.iloc[i].HomeTeam].append(AGHCC)
        teams[playing_stat.iloc[i].AwayTeam].append(AGACC)
    
    # Create a dataframe for shots fired (goals scored) where rows are teams and cols are matchweek.
    Corners = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    Corners[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        Corners[i] = Corners[i] + Corners[i-1]
    return Corners


def get_corners_agg(playing_stat):
    CF = get_corners_fired(playing_stat)
    CC = get_corners_conceived(playing_stat)
   
    j = 0
    AGHCF = []
    AGACF = []
    AGHCC = []
    AGACC = []

    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        AGHCF.append(CF.loc[ht][j])
        AGACF.append(CF.loc[at][j])
        AGHCC.append(CC.loc[ht][j])
        AGACC.append(CC.loc[at][j])
        
        if ((i + 1)% 9) == 0:
            j = j + 1
        
    playing_stat['AGHCF'] = AGHCF
    playing_stat['AGACF'] = AGACF
    playing_stat['AGHCC'] = AGHCC
    playing_stat['AGACC'] = AGACC
    
    return playing_stat

# %%
playing_statistics_05 = get_corners_agg(playing_statistics_05)
playing_statistics_06 = get_corners_agg(playing_statistics_06)
playing_statistics_07 = get_corners_agg(playing_statistics_07)

playing_statistics_09 = get_corners_agg(playing_statistics_09)
playing_statistics_11 = get_corners_agg(playing_statistics_11)
playing_statistics_13 = get_corners_agg(playing_statistics_13)
playing_statistics_15 = get_corners_agg(playing_statistics_15)
playing_statistics_17 = get_corners_agg(playing_statistics_17)
playing_statistics_19 = get_corners_agg(playing_statistics_19)

playing_statistics_21= get_corners_agg(playing_statistics_21)
playing_statistics_23= get_corners_agg(playing_statistics_23)
playing_statistics_25= get_corners_agg(playing_statistics_25)
playing_statistics_27= get_corners_agg(playing_statistics_27)
playing_statistics_28= get_corners_agg(playing_statistics_28)
playing_statistics_29= get_corners_agg(playing_statistics_29)
playing_statistics_30= get_corners_agg(playing_statistics_30)
# Out:
# <ipython-input-172-e6a2ea22a806>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGHCF'] = AGHCF
# <ipython-input-172-e6a2ea22a806>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGACF'] = AGACF
# <ipython-input-172-e6a2ea22a806>:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
playing_statistics_09[['Date', "HomeTeam", "AwayTeam", "HC", "AC",'AGHCF', "AGACF", "AGHCC", "AGACC"]].head(50)
# Out:
#           Date       HomeTeam       AwayTeam  HC  AC  AGHCF  AGACF  AGHCC  \
# 0   2008-08-15  Bayern Munich        Hamburg   2   2      0      0      0
# 1   2008-08-16      Bielefeld  Werder Bremen   4   4      0      0      0
# 2   2008-08-16        Cottbus     Hoffenheim   4   2      0      0      0
# 3   2008-08-16      Karlsruhe         Bochum   1   4      0      0      0
# 4   2008-08-16     Leverkusen       Dortmund   7   3      0      0      0
# 5   2008-08-16     Schalke 04       Hannover   6   7      0      0      0
# 6   2008-08-16      Wolfsburg        FC Koln  10   3      0      0      0
# 7   2008-08-17  Ein Frankfurt         Hertha  11   2      0      0      0
# 8   2008-08-17     M'gladbach      Stuttgart   4   3      0      0      0
# 9   2008-08-22       Hannover        Cottbus   6   1      7      4      6
# 10  2008-08-23       Dortmund  Bayern Munich   6  14      3      2      7
# 11  2008-08-23        Hamburg      Karlsruhe   6   6      2      1      2
# ...

# %% [markdown]
# Yellow Cards

# %%
# Gets yellow cards agg arranged by teams and matchweek
def get_yellow(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGHY = playing_stat.iloc[i]['HY']
        # aggregated Home Team yellow cards
        AGAY = playing_stat.iloc[i]['AY']
        # aggregated Away Team yellow cards
        teams[playing_stat.iloc[i].HomeTeam].append(AGHY)
        teams[playing_stat.iloc[i].AwayTeam].append(AGAY)
    
    # Create a dataframe for shots fired (goals scored) where rows are teams and cols are matchweek.
    Yellow = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    Yellow[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        Yellow[i] = Yellow[i] + Yellow[i-1]
    return Yellow


def get_yellow_agg(playing_stat):
    Y = get_yellow(playing_stat)
   
    j = 0
    AGHY = []
    AGAY = []

    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        AGHY.append(Y.loc[ht][j])
        AGAY.append(Y.loc[at][j])
        
        if ((i + 1)% 9) == 0:
            j = j + 1
        
    playing_stat['AGHY'] = AGHY
    playing_stat['AGAY'] = AGAY
    return playing_stat

# %%
playing_statistics_05 = get_yellow_agg(playing_statistics_05)
playing_statistics_06 = get_yellow_agg(playing_statistics_06)
playing_statistics_07 = get_yellow_agg(playing_statistics_07)

playing_statistics_09 = get_yellow_agg(playing_statistics_09)
playing_statistics_11 = get_yellow_agg(playing_statistics_11)
playing_statistics_13 = get_yellow_agg(playing_statistics_13)
playing_statistics_15 = get_yellow_agg(playing_statistics_15)
playing_statistics_17 = get_yellow_agg(playing_statistics_17)
playing_statistics_19 = get_yellow_agg(playing_statistics_19)

playing_statistics_21= get_yellow_agg(playing_statistics_21)
playing_statistics_23= get_yellow_agg(playing_statistics_23)
playing_statistics_25= get_yellow_agg(playing_statistics_25)
playing_statistics_27= get_yellow_agg(playing_statistics_27)
playing_statistics_28= get_yellow_agg(playing_statistics_28)
playing_statistics_29= get_yellow_agg(playing_statistics_29)
playing_statistics_30= get_yellow_agg(playing_statistics_30)
# Out:
# <ipython-input-175-dc9701e46946>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGHY'] = AGHY
# <ipython-input-175-dc9701e46946>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGAY'] = AGAY

# %%
playing_statistics_28[['Date', "HomeTeam", "AwayTeam", "HY", "AY",'AGHY', "AGAY"]].head(50)
# Out:
#           Date        HomeTeam        AwayTeam  HY  AY  AGHY  AGAY
# 0   2018-08-03         Hamburg   Holstein Kiel   1   3     0     0
# 1   2018-08-04          Bochum         FC Koln   3   2     0     0
# 2   2018-08-04  Greuther Furth      Sandhausen   1   1     0     0
# 3   2018-08-04      Regensburg      Ingolstadt   1   3     0     0
# 4   2018-08-05       Darmstadt       Paderborn   3   4     0     0
# 5   2018-08-05      Heidenheim       Bielefeld   1   1     0     0
# 6   2018-08-05       Magdeburg        St Pauli   0   1     0     0
# 7   2018-08-05    Union Berlin  Erzgebirge Aue   2   3     0     0
# 8   2018-08-06         Dresden        Duisburg   0   3     0     0
# 9   2018-08-10      Ingolstadt  Greuther Furth   1   3     3     1
# 10  2018-08-10       Paderborn      Regensburg   1   4     4     1
# 11  2018-08-10        St Pauli       Darmstadt   3   3     1     3
# 12  2018-08-11       Bielefeld         Dresden   1   3     1     0
# ...

# %% [markdown]
# Red cards

# %%
# Gets red cards agg arranged by teams and matchweek
def get_red(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []
    
    # the value corresponding to keys is a list containing the match location.
    for i in range(len(playing_stat)):
        AGHR = playing_stat.iloc[i]['HR']
        # aggregated Home Team yellow cards
        AGAR = playing_stat.iloc[i]['AR']
        # aggregated Away Team yellow cards
        teams[playing_stat.iloc[i].HomeTeam].append(AGHR)
        teams[playing_stat.iloc[i].AwayTeam].append(AGAR)
    
    # Create a dataframe for shots fired (goals scored) where rows are teams and cols are matchweek.
    Red = pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T
    Red[0] = 0
    # Aggregate to get uptil that point
    for i in range(2,35):
        Red[i] = Red[i] + Red[i-1]
    return Red


def get_red_agg(playing_stat):
    R = get_red(playing_stat)
   
    j = 0
    AGHR = []
    AGAR = []

    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        AGHR.append(R.loc[ht][j])
        AGAR.append(R.loc[at][j])
        
        if ((i + 1)% 9) == 0:
            j = j + 1
        
    playing_stat['AGHR'] = AGHR
    playing_stat['AGAR'] = AGAR
    return playing_stat

# %%
playing_statistics_05 = get_red_agg(playing_statistics_05)
playing_statistics_06 = get_red_agg(playing_statistics_06)
playing_statistics_07 = get_red_agg(playing_statistics_07)

playing_statistics_09 = get_red_agg(playing_statistics_09)
playing_statistics_11 = get_red_agg(playing_statistics_11)
playing_statistics_13 = get_red_agg(playing_statistics_13)
playing_statistics_15 = get_red_agg(playing_statistics_15)
playing_statistics_17 = get_red_agg(playing_statistics_17)
playing_statistics_19 = get_red_agg(playing_statistics_19)

playing_statistics_21= get_red_agg(playing_statistics_21)
playing_statistics_23= get_red_agg(playing_statistics_23)
playing_statistics_25= get_red_agg(playing_statistics_25)
playing_statistics_27= get_red_agg(playing_statistics_27)
playing_statistics_28= get_red_agg(playing_statistics_28)
playing_statistics_29= get_red_agg(playing_statistics_29)
playing_statistics_30= get_red_agg(playing_statistics_30)
# Out:
# <ipython-input-178-b8b299be30fc>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGHR'] = AGHR
# <ipython-input-178-b8b299be30fc>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AGAR'] = AGAR

# %%
playing_statistics_29[['Date', "HomeTeam", "AwayTeam", "HR", "AR",'AGHR', "AGAR"]].head(50)
# Out:
#           Date            HomeTeam            AwayTeam  HR  AR  AGHR  AGAR
# 0   2019-08-16       Bayern Munich              Hertha   0   0     0     0
# 1   2019-08-17            Dortmund            Augsburg   0   0     0     0
# 2   2019-08-17            Freiburg               Mainz   0   0     0     0
# 3   2019-08-17          Leverkusen           Paderborn   0   0     0     0
# 4   2019-08-17       Werder Bremen  Fortuna Dusseldorf   0   0     0     0
# 5   2019-08-17           Wolfsburg             FC Koln   0   0     0     0
# 6   2019-08-17          M'gladbach          Schalke 04   0   0     0     0
# 7   2019-08-18       Ein Frankfurt          Hoffenheim   0   0     0     0
# 8   2019-08-18        Union Berlin          RB Leipzig   0   0     0     0
# 9   2019-08-23             FC Koln            Dortmund   0   0     0     0
# 10  2019-08-24            Augsburg        Union Berlin   0   1     0     0
# ...

# %% [markdown]
# GET RESPECTIVE POINTS:

# %%
def get_points(result):
    if result == 'W':
        return 3
    elif result == 'D':
        return 1
    else:
        return 0
    

def get_cuml_points(matchres):
    matchres_points = matchres.applymap(get_points)
    for i in range(2,35):
        matchres_points[i] = matchres_points[i] + matchres_points[i-1]
        
    matchres_points.insert(column =0, loc = 0, value = [0*i for i in range(18)])
    return matchres_points


def get_matchres(playing_stat):
    # Create a dictionary with team names as keys
    teams = {}
    for i in playing_stat.groupby('HomeTeam').mean().T.columns:
        teams[i] = []

    # the value corresponding to keys is a list containing the match result
    for i in range(len(playing_stat)):
        if playing_stat.iloc[i].FTR == 'H':
            teams[playing_stat.iloc[i].HomeTeam].append('W')
            teams[playing_stat.iloc[i].AwayTeam].append('L')
        elif playing_stat.iloc[i].FTR == 'A':
            teams[playing_stat.iloc[i].AwayTeam].append('W')
            teams[playing_stat.iloc[i].HomeTeam].append('L')
        else:
            teams[playing_stat.iloc[i].AwayTeam].append('D')
            teams[playing_stat.iloc[i].HomeTeam].append('D')
            
    return pd.DataFrame(data=teams, index = [i for i in range(1,35)]).T

def get_agg_points(playing_stat):
    matchres = get_matchres(playing_stat)
    cum_pts = get_cuml_points(matchres)
    HTP = []
    ATP = []
    j = 0
    for i in range(306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        HTP.append(cum_pts.loc[ht][j])
        ATP.append(cum_pts.loc[at][j])

        if ((i + 1)% 9) == 0:
            j = j + 1
            
    playing_stat['HTP'] = HTP
    playing_stat['ATP'] = ATP
    return playing_stat

# %%
# Apply to each dataset

playing_statistics_05 = get_agg_points(playing_statistics_05)
playing_statistics_06 = get_agg_points(playing_statistics_06)
playing_statistics_07 = get_agg_points(playing_statistics_07)

playing_statistics_09 = get_agg_points(playing_statistics_09)
playing_statistics_11 = get_agg_points(playing_statistics_11)
playing_statistics_13 = get_agg_points(playing_statistics_13)
playing_statistics_15 = get_agg_points(playing_statistics_15)
playing_statistics_17 = get_agg_points(playing_statistics_17)
playing_statistics_19 = get_agg_points(playing_statistics_19)

playing_statistics_21= get_agg_points(playing_statistics_21)
playing_statistics_23= get_agg_points(playing_statistics_23)
playing_statistics_25= get_agg_points(playing_statistics_25)
playing_statistics_27= get_agg_points(playing_statistics_27)
playing_statistics_28= get_agg_points(playing_statistics_28)
playing_statistics_29= get_agg_points(playing_statistics_29)
playing_statistics_30= get_agg_points(playing_statistics_30)
# Out:
# <ipython-input-181-ebeaecbf5df5>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['HTP'] = HTP
# <ipython-input-181-ebeaecbf5df5>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['ATP'] = ATP

# %%
playing_statistics_09[['Date', "HomeTeam", "AwayTeam", "FTHG", "FTAG","HTP", "ATP"]].head(50)
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG  HTP  ATP
# 0   2008-08-15  Bayern Munich        Hamburg     2     2    0    0
# 1   2008-08-16      Bielefeld  Werder Bremen     2     2    0    0
# 2   2008-08-16        Cottbus     Hoffenheim     0     3    0    0
# 3   2008-08-16      Karlsruhe         Bochum     1     0    0    0
# 4   2008-08-16     Leverkusen       Dortmund     2     3    0    0
# 5   2008-08-16     Schalke 04       Hannover     3     0    0    0
# 6   2008-08-16      Wolfsburg        FC Koln     2     1    0    0
# 7   2008-08-17  Ein Frankfurt         Hertha     0     2    0    0
# 8   2008-08-17     M'gladbach      Stuttgart     1     3    0    0
# 9   2008-08-22       Hannover        Cottbus     0     0    0    0
# 10  2008-08-23       Dortmund  Bayern Munich     1     1    3    1
# 11  2008-08-23        Hamburg      Karlsruhe     2     1    1    3
# 12  2008-08-23         Hertha      Bielefeld     1     1    3    1
# ...

# %% [markdown]
# GET TEAM FORM:

# %%
def get_form(playing_stat,num):
    form = get_matchres(playing_stat)
    form_final = form.copy()
    for i in range(num,35):
        form_final[i] = ''
        j = 0
        while j < num:
            form_final[i] += form[i-j]
            j += 1           
    return form_final

def add_form(playing_stat,num):
    form = get_form(playing_stat,num)
    h = ['M' for i in range(num * 9)]  # since form is not available for n MW (n*10)
    a = ['M' for i in range(num * 9)]
    
    j = num
    for i in range((num*9),306):
        ht = playing_stat.iloc[i].HomeTeam
        at = playing_stat.iloc[i].AwayTeam
        
        past = form.loc[ht][j]               # get past n results
        h.append(past[num-1])                    # 0 index is most recent
        
        past = form.loc[at][j]               # get past n results.
        a.append(past[num-1])                   # 0 index is most recent
        
        if ((i + 1)% 9) == 0:
            j = j + 1

    playing_stat['HM' + str(num)] = h                 
    playing_stat['AM' + str(num)] = a

    
    return playing_stat


def add_form_df(playing_statistics):
    playing_statistics = add_form(playing_statistics,1)
    playing_statistics = add_form(playing_statistics,2)
    playing_statistics = add_form(playing_statistics,3)
    playing_statistics = add_form(playing_statistics,4)
    playing_statistics = add_form(playing_statistics,5)
    return playing_statistics

# %%
# Make changes to df
playing_statistics_05 = add_form_df(playing_statistics_05)
playing_statistics_06 = add_form_df(playing_statistics_06)
playing_statistics_07 = add_form_df(playing_statistics_07)

playing_statistics_09 = add_form_df(playing_statistics_09)
playing_statistics_11 = add_form_df(playing_statistics_11)
playing_statistics_13 = add_form_df(playing_statistics_13)
playing_statistics_15 = add_form_df(playing_statistics_15)
playing_statistics_17 = add_form_df(playing_statistics_17)
playing_statistics_19 = add_form_df(playing_statistics_19)

playing_statistics_21= add_form_df(playing_statistics_21)
playing_statistics_23= add_form_df(playing_statistics_23)
playing_statistics_25= add_form_df(playing_statistics_25)
playing_statistics_27= add_form_df(playing_statistics_27)
playing_statistics_28= add_form_df(playing_statistics_28)
playing_statistics_29= add_form_df(playing_statistics_29)
playing_statistics_30= add_form_df(playing_statistics_30)
# Out:
# <ipython-input-184-3d357d7021db>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['HM' + str(num)] = h
# <ipython-input-184-3d357d7021db>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['AM' + str(num)] = a

# %% [markdown]
# Get MatchWeek:

# %%
def get_mw(playing_stat):
    j = 1
    MatchWeek = []
    for i in range(306):
        MatchWeek.append(j)
        if ((i + 1)% 9) == 0:
            j = j + 1
    playing_stat['MW'] = MatchWeek
    return playing_stat

# %%
playing_statistics_05 = get_mw(playing_statistics_05)
playing_statistics_06 = get_mw(playing_statistics_06)
playing_statistics_07 = get_mw(playing_statistics_07)

playing_statistics_09 = get_mw(playing_statistics_09)
playing_statistics_11 = get_mw(playing_statistics_11)
playing_statistics_13 = get_mw(playing_statistics_13)
playing_statistics_15 = get_mw(playing_statistics_15)
playing_statistics_17 = get_mw(playing_statistics_17)
playing_statistics_19 = get_mw(playing_statistics_19)

playing_statistics_21= get_mw(playing_statistics_21)
playing_statistics_23= get_mw(playing_statistics_23)
playing_statistics_25= get_mw(playing_statistics_25)
playing_statistics_27= get_mw(playing_statistics_27)
playing_statistics_28= get_mw(playing_statistics_28)
playing_statistics_29= get_mw(playing_statistics_29)
playing_statistics_30= get_mw(playing_statistics_30)
# Out:
# <ipython-input-186-cdb248787c58>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_stat['MW'] = MatchWeek

# %%
playing_statistics_27
# Out:
#            Date            HomeTeam       AwayTeam  FTHG  FTAG FTR  HS  AS  \
# 0    2018-08-24       Bayern Munich     Hoffenheim     3     1   H  16   8
# 1    2018-08-25  Fortuna Dusseldorf       Augsburg     1     2   A   9  14
# 2    2018-08-25            Freiburg  Ein Frankfurt     0     2   A  22  10
# 3    2018-08-25              Hertha       Nurnberg     1     0   H  10  12
# 4    2018-08-25          M'gladbach     Leverkusen     2     0   H  17  13
# ..          ...                 ...            ...   ...   ...  ..  ..  ..
# 301  2019-05-18               Mainz     Hoffenheim     4     2   H  22  19
# 302  2019-05-18          M'gladbach       Dortmund     0     2   A   7  12
# 303  2019-05-18          Schalke 04      Stuttgart     0     0   D  12  16
# 304  2019-05-18       Werder Bremen     RB Leipzig     2     1   H   6  10
# 305  2019-05-18           Wolfsburg       Augsburg     8     1   H  18  12
#
#      HST  AST  ...  AM1  HM2  AM2  HM3  AM3  HM4  AM4  HM5  AM5  MW
# ...

# %% [markdown]
# FINAL DATAFRAME

# %%
playing_stat = pd.concat([playing_statistics_05,
                         playing_statistics_06,
                         playing_statistics_07,
                         playing_statistics_09,
                         playing_statistics_11,
                         playing_statistics_13,
                         playing_statistics_15,
                         playing_statistics_17,
                         playing_statistics_19,
                         playing_statistics_21,
                         playing_statistics_23,
                         playing_statistics_25,
                         playing_statistics_27,
                         playing_statistics_28,
                         playing_statistics_29,
                         playing_statistics_30], ignore_index=True)

# %%
playing_stat
# Out:
#             Date       HomeTeam        AwayTeam  FTHG  FTAG FTR  HS  AS  HST  \
# 0     2006-08-11  Bayern Munich        Dortmund     2     0   H  12  16    9
# 1     2006-08-12        Hamburg       Bielefeld     1     1   D  26  10   19
# 2     2006-08-12     Leverkusen          Aachen     3     0   H  20   8   11
# 3     2006-08-12          Mainz          Bochum     2     1   H  11  19    5
# 4     2006-08-12     M'gladbach         Cottbus     2     0   H  13  11    8
# ...          ...            ...             ...   ...   ...  ..  ..  ..  ...
# 4891  2020-06-28       Hannover          Bochum     2     0   H  11  20    2
# 4892  2020-06-28  Holstein Kiel        Nurnberg     1     1   D  13  13    5
# 4893  2020-06-28     Regensburg  Erzgebirge Aue     1     2   A  19  16    6
# 4894  2020-06-28      Stuttgart       Darmstadt     1     3   A  11   6    3
# 4895  2020-06-28          Wehen        St Pauli     5     3   H  23  12    8
#
# ...

# %%
# Gets the form points.
def get_form_points(string):
    sum = 0
    for letter in string:
        sum += get_points(letter)
    return sum

playing_stat['HTFormPtsStr'] = playing_stat['HM1'] + playing_stat['HM2'] + playing_stat['HM3'] + playing_stat['HM4'] + playing_stat['HM5']
playing_stat['ATFormPtsStr'] = playing_stat['AM1'] + playing_stat['AM2'] + playing_stat['AM3'] + playing_stat['AM4'] + playing_stat['AM5']

playing_stat['HTFormPts'] = playing_stat['HTFormPtsStr'].apply(get_form_points)
playing_stat['ATFormPts'] = playing_stat['ATFormPtsStr'].apply(get_form_points)

# Identify Win/Loss Streaks if any.
def get_3game_ws(string):
    if string[-3:] == 'WWW':
        return 1
    else:
        return 0
    
def get_5game_ws(string):
    if string == 'WWWWW':
        return 1
    else:
        return 0
    
def get_3game_ls(string):
    if string[-3:] == 'LLL':
        return 1
    else:
        return 0
    
def get_5game_ls(string):
    if string == 'LLLLL':
        return 1
    else:
        return 0
    
playing_stat['HTWinStreak3'] = playing_stat['HTFormPtsStr'].apply(get_3game_ws)
playing_stat['HTWinStreak5'] = playing_stat['HTFormPtsStr'].apply(get_5game_ws)
playing_stat['HTLossStreak3'] = playing_stat['HTFormPtsStr'].apply(get_3game_ls)
playing_stat['HTLossStreak5'] = playing_stat['HTFormPtsStr'].apply(get_5game_ls)

playing_stat['ATWinStreak3'] = playing_stat['ATFormPtsStr'].apply(get_3game_ws)
playing_stat['ATWinStreak5'] = playing_stat['ATFormPtsStr'].apply(get_5game_ws)
playing_stat['ATLossStreak3'] = playing_stat['ATFormPtsStr'].apply(get_3game_ls)
playing_stat['ATLossStreak5'] = playing_stat['ATFormPtsStr'].apply(get_5game_ls)

playing_stat.keys()
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS', 'AS',
#        'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'HTGS',
#        'ATGS', 'HTGC', 'ATGC', 'AGHSF', 'AGASF', 'AGHSC', 'AGASC', 'AGHSTF',
#        'AGASTF', 'AGHSTC', 'AGASTC', 'AGHF', 'AGAF', 'AGHCF', 'AGACF', 'AGHCC',
#        'AGACC', 'AGHY', 'AGAY', 'AGHR', 'AGAR', 'HTP', 'ATP', 'HM1', 'AM1',
#        'HM2', 'AM2', 'HM3', 'AM3', 'HM4', 'AM4', 'HM5', 'AM5', 'MW',
#        'HTFormPtsStr', 'ATFormPtsStr', 'HTFormPts', 'ATFormPts',
#        'HTWinStreak3', 'HTWinStreak5', 'HTLossStreak3', 'HTLossStreak5',
#        'ATWinStreak3', 'ATWinStreak5', 'ATLossStreak3', 'ATLossStreak5'],
#       dtype='object')

# %%
# Get Goal Difference
playing_stat['HTGD'] = playing_stat['HTGS'] - playing_stat['HTGC']
playing_stat['ATGD'] = playing_stat['ATGS'] - playing_stat['ATGC']

# Diff in points
playing_stat['DiffPts'] = playing_stat['HTP'] - playing_stat['ATP']
playing_stat['DiffFormPts'] = playing_stat['HTFormPts'] - playing_stat['ATFormPts']

# Diff in Shots fired
playing_stat['HTSD'] = playing_stat['AGHSF'] - playing_stat['AGHSC']
playing_stat['ATSD'] = playing_stat['AGASF'] - playing_stat['AGASC']

# Diff in shots on target
playing_stat['HTSTD'] = playing_stat['AGHSTF'] - playing_stat['AGHSTC']
playing_stat['ATSTD'] = playing_stat['AGASTF'] - playing_stat['AGASTC']

# Diff in corners
playing_stat['HTCD'] = playing_stat['AGHCF'] - playing_stat['AGHCC']
playing_stat['ATCD'] = playing_stat['AGACF'] - playing_stat['AGACC']

# %%
# Datensatz nicht gescaled
#playing_stat_raw = playing_stat
#playing_stat_raw.to_csv(loc + "2019_2020_ingame_1und2_raw.csv")

# %%
# Scale DiffPts , DiffFormPts, HTGD, ATGD by Matchweek.
cols = ['HTGD','ATGD','DiffPts','DiffFormPts','HTP','ATP', "HTSD", "ATSD", "HTSTD", "ATSTD", "HTCD", "ATCD",
        "AGHY", "AGHR", "AGAR", "AGHF", "AGAF", "AGAY", 'AGHSF','AGASF', 'AGHSC', 'AGASC', 'AGHSTF', 'AGASTF', 
        'AGHSTC', 'AGASTC', 'AGHCF', 'AGACF', 'AGHCC', 'AGACC']
playing_stat.MW = playing_stat.MW.astype(float)

for col in cols:
    playing_stat[col] = playing_stat[col] / playing_stat.MW

# %%
playing_stat.MW
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 4891    34.0
# 4892    34.0
# 4893    34.0
# 4894    34.0
# 4895    34.0
# Name: MW, Length: 4896, dtype: float64

# %%
playing_stat.to_csv(loc + "final_dataset_buli_1_2.csv")
# playing_stat_test.to_csv(loc+"test.csv")
